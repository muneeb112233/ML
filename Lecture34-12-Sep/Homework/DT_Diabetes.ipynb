# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('diabetes.csv')
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 749            6      162             62              0        0  24.3
# 67             2      109             92              0        0  42.7
# 432            1       80             74             11       60  30.0
# 550            1      116             70             28        0  27.4
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 749                     0.178   50        1
# 67                      0.845   54        0
# 432                     0.527   22        0
# 550                     0.204   21        0
# 763                     0.171   63        0

# %%
print(f"{df.shape[0]} rows and {df.shape[1]} columns in the dataset.")
print(f"Columns in the dataset: {df.columns.tolist()}")
print(f"Missing values in the dataset:\n{df.isnull().sum()}")
print(f"Data types of the columns:\n{df.dtypes}")
# Out:
# 768 rows and 9 columns in the dataset.
# Columns in the dataset: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
# Missing values in the dataset:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# Data types of the columns:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# Data is not Dirty and No need for cleaning or dropping Columns or Rows

# %%
print(f"Info of the dataset:\n{df.info()}")
print(f"Statistical summary of the dataset:\n{df.describe()}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Info of the dataset:
# None
# Statistical summary of the dataset:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
Dtree = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)

# %%
Dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
y_pred = Dtree.predict(X_test)

# %%
print(f"Score on Testing Data is {accuracy_score(y_test, y_pred)}")
print(f"Score on training Data is {Dtree.score(X_train, y_train)}")
# Out:
# Score on Testing Data is 0.7207792207792207
# Score on training Data is 0.7964169381107492

# %%
for i in range(1, 21):
    trees = DecisionTreeClassifier(criterion='gini', max_depth=i, random_state=42)
    trees.fit(X_train, y_train)
    y_pred = trees.predict(X_test)
    print(f"Max Depth: {i}, Score on Test data: {accuracy_score(y_test, y_pred)}, Score on training data: {accuracy_score(y_train, trees.predict(X_train))}")
# Out:
# Max Depth: 1, Score on Test data: 0.6948051948051948, Score on training data: 0.745928338762215
# Max Depth: 2, Score on Test data: 0.7272727272727273, Score on training data: 0.7833876221498371
# Max Depth: 3, Score on Test data: 0.7207792207792207, Score on training data: 0.7964169381107492
# Max Depth: 4, Score on Test data: 0.6948051948051948, Score on training data: 0.8175895765472313
# Max Depth: 5, Score on Test data: 0.6623376623376623, Score on training data: 0.8550488599348535
# Max Depth: 6, Score on Test data: 0.7142857142857143, Score on training data: 0.8827361563517915
# Max Depth: 7, Score on Test data: 0.6948051948051948, Score on training data: 0.9185667752442996
# Max Depth: 8, Score on Test data: 0.6948051948051948, Score on training data: 0.9429967426710097
# Max Depth: 9, Score on Test data: 0.6688311688311688, Score on training data: 0.9674267100977199
# Max Depth: 10, Score on Test data: 0.6623376623376623, Score on training data: 0.9837133550488599
# Max Depth: 11, Score on Test data: 0.6818181818181818, Score on training data: 0.99185667752443
# Max Depth: 12, Score on Test data: 0.6818181818181818, Score on training data: 0.995114006514658
# Max Depth: 13, Score on Test data: 0.6558441558441559, Score on training data: 0.998371335504886
# Max Depth: 14, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 15, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 16, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 17, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 18, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 19, Score on Test data: 0.6428571428571429, Score on training data: 1.0
# Max Depth: 20, Score on Test data: 0.6428571428571429, Score on training data: 1.0

# %% [markdown]
# 3 Depth Given the best result after depth 13 its all over fitting

# %%
from sklearn import tree
plt.figure(figsize=(12,8), dpi= 600)
plt.title("Decision Tree for Diabetes Prediction")
tree.plot_tree(Dtree, feature_names=X.columns.tolist(), class_names=['No Diabetes', 'Diabetes'],filled=True)

plt.show()

# %%
feat_importances = pd.Series(Dtree.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title("Feature Importance in Decision Tree for Diabetes Prediction")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
# Out:
# Confusion Matrix:
# [[70 27]
#  [28 29]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.72        97
#            1       0.52      0.51      0.51        57
#
#     accuracy                           0.64       154
#    macro avg       0.62      0.62      0.62       154
# weighted avg       0.64      0.64      0.64       154

# %% [markdown]
# ### Classification Report — Class by Class
#
# **Class 1 (Diabetes):** TP=29, FP=27, FN=28 | **Class 0 (No):** flip roles → TP=70, FP=28, FN=27
#
# | Metric | Formula | Class 1 | Class 0 |
# |---|---|---|---|
# | Precision | TP/(TP+FP) | 29/56 = **0.52** | 70/98 = **0.71** |
# | Recall | TP/(TP+FN) | 29/57 = **0.51** | 70/97 = **0.72** |
# | F1 | 2PR/(P+R) | **0.51** | **0.72** |
# | Support | actual count | 57 | 97 |
#
# - **Precision** → when model says this class, how often right?
# - **Recall** → of all real cases, how many caught?
# - **F1** → balance of both.
# - **macro avg** = plain mean (0.62) · **weighted avg** = weighted by support (0.64)
#
# **Takeaway:** model spots healthy (0.7) far better than diabetic (0.5) ⚠️.
# For medical data, recall on class 1 matters most → fix with SMOTE, `max_depth` tuning, or threshold adjustment.

# %%
group_names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
group_counts = [f"{v}" for v in cm.flatten()]
labels = np.asarray([f"{n}\n{c}" for n, c in zip(group_names, group_counts)]).reshape(2, 2)

sns.heatmap(cm, annot=labels, fmt='', cmap='Blues',
            xticklabels=['Pred: No Diabetes', 'Pred: Diabetes'],
            yticklabels=['Actual: No Diabetes', 'Actual: Diabetes'])
plt.show()

# %%
import pickle
with open('Dtree_model.pkl', 'wb') as f:
    pickle.dump(Dtree,f)
